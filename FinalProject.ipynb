# %% [markdown]
# <a href="https://colab.research.google.com/github/Chanakarn06/data_viz_2022/blob/main/FinalProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Link

# %% [markdown]
# [Dashboard Project Link](https://datastudio.google.com/s/mEVidNHCTqg)

# %% [markdown]
# # Import Data

# %%
import pandas as pd #เพื่อใช้ทำงานกับข้อมูลที่เป็นรูปแบบตาราง
import os           #เพื่อจัดการกับไฟล์ และ ตัว path ที่เราจะนำเข้า

# %%
from google.colab import drive # เชื่อมบัญชีกับ google drive
drive.mount('/content/drive') # เช็คว่าเชื่อมติดหรือไม่
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = '/content/drive/My Drive/Project_Dashboard2022'

# %% [markdown]
# ## Data 1 เป็น data พิกัดของโรงพยาบาล

# %%
data1 = pd.read_excel(os.path.join(path,'citizeninfo_health_20200314 (5).xlsx'))
data1
# Out:
#         รหัสหน่วยงาน        กระทรวง               กรม  \
# 0      8899021500001  กระทรวงกลาโหม    กรมแพทย์ทหารบก
# 1      8899021200003  กระทรวงกลาโหม  กรมแพทย์ทหารเรือ
# 2      8899021200001  กระทรวงกลาโหม  กรมแพทย์ทหารเรือ
# 3       111020400029  กระทรวงกลาโหม          กองทัพบก
# 4       113020400030  กระทรวงกลาโหม          กองทัพบก
# ...              ...            ...               ...
# 10709  8899417700034  กรุงเทพมหานคร       สำนักอนามัย
# 10710  8899417700072  กรุงเทพมหานคร       สำนักอนามัย
# 10711  8899417700052  กรุงเทพมหานคร       สำนักอนามัย
# 10712  8899417700073  กรุงเทพมหานคร       สำนักอนามัย
# 10713  8899417700032  กรุงเทพมหานคร       สำนักอนามัย
#
#                                           หน่วยงาน        จังหวัด  \
# 0                         โรงพยาบาลค่ายพิชัยดาบหัก      อุตรดิตถ์
# 1               โรงพยาบาลสมเด็จพระนางเจ้าสิริกิติ์         ชลบุรี
# 2                         โรงพยาบาลทหารเรือกรุงเทพ  กรุงเทพมหานคร
# ...

# %% [markdown]
# ## Data 2 Data COVID-19 ประจำวัน เริ่มตั้งแต่วันที่ 12 สิงหาคม 2564 ถึง 25 ตุลาคม 2564

# %%
data2 = pd.read_excel(os.path.join(path,'confirmed-cases-since-120864.xlsx'))
data2
# Out:
#              No. announce_date Notified date   sex   age Unit nationality  \
# 0         816990    2021-08-12    2021-08-11   ชาย   7.0   ปี    Thailand
# 1         816991    2021-08-12    2021-08-11   ชาย   1.0   ปี    Thailand
# 2         816992    2021-08-12    2021-08-11   ชาย  35.0   ปี    Thailand
# 3         816993    2021-08-12    2021-08-11  หญิง  33.0   ปี    Thailand
# 4         816994    2021-08-12    2021-08-11  หญิง  14.0   ปี    Thailand
# ...          ...           ...           ...   ...   ...  ...         ...
# 1042163  1859153    2021-10-25    2021-10-24   ชาย  45.0   ปี         NaN
# 1042164  1859154    2021-10-25    2021-10-24   ชาย  31.0   ปี         NaN
# 1042165  1859155    2021-10-25    2021-10-24   ชาย  31.0   ปี         NaN
# 1042166  1859156    2021-10-25    2021-10-24   ชาย  24.0   ปี         NaN
# 1042167  1859157    2021-10-25    2021-10-24   ชาย  25.0   ปี         NaN
#
#         province_of_isolation                                         risk  \
# ...

# %% [markdown]
# ## Data 3 Data COVID-19 ประจำวัน เริ่มตั้งแต่วันที่ 26 ตุลาคม 2564 ถึง 27 กุมภาพันธ์ 2565

# %%
data3 = pd.read_excel(os.path.join(path,'confirmed-cases-since-271064.xlsx'))
data3
# Out:
#              No. announce_date Notified date   sex  age Unit nationality  \
# 0        1859158    2021-10-26    2021-10-25   ชาย   20   ปี    Thailand
# 1        1859159    2021-10-26    2021-10-25  หญิง   42   ปี    Thailand
# 2        1859160    2021-10-26    2021-10-25  หญิง   33   ปี    Thailand
# 3        1859161    2021-10-26    2021-10-25  หญิง   52   ปี    Thailand
# 4        1859162    2021-10-26    2021-10-25  หญิง   84   ปี    Thailand
# ...          ...           ...           ...   ...  ...  ...         ...
# 1010454  2869612    2022-02-27    2022-02-26   ชาย  NaN  NaN         NaN
# 1010455  2869613    2022-02-27    2022-02-26   ชาย  NaN  NaN         NaN
# 1010456  2869614    2022-02-27    2022-02-26   ชาย  NaN  NaN         NaN
# 1010457  2869615    2022-02-27    2022-02-26   ชาย  NaN  NaN         NaN
# 1010458  2869616    2022-02-27    2022-02-26   ชาย  NaN  NaN         NaN
#
#         province_of_isolation                                           risk  \
# ...

# %% [markdown]
# ## Data 4 Data COVID-19 ประจำวัน เริ่มตั้งแต่วันที่ 28 กุมภาพันธ์ 2565 ถึง 17 มีนาคม 2565

# %%
data4 = pd.read_excel(os.path.join(path,'confirmed-cases-since-280265 (1).xlsx'))
data4
# Out:
#             No. announce_date Notified date   sex   age Unit nationality  \
# 0       2869617    2022-02-28    2022-02-27   ชาย  41.0   ปี    Thailand
# 1       2869618    2022-02-28    2022-02-27  หญิง  45.0   ปี    Thailand
# 2       2869619    2022-02-28    2022-02-27  หญิง  40.0   ปี    Thailand
# 3       2869620    2022-02-28    2022-02-27   ชาย  44.0   ปี    Thailand
# 4       2869621    2022-02-28    2022-02-27   ชาย  11.0   ปี    Thailand
# ...         ...           ...           ...   ...   ...  ...         ...
# 406477  3276094    2022-03-17    2022-03-16   ชาย   NaN  NaN         NaN
# 406478  3276095    2022-03-17    2022-03-16   ชาย   NaN  NaN         NaN
# 406479  3276096    2022-03-17    2022-03-16   ชาย   NaN  NaN         NaN
# 406480  3276097    2022-03-17    2022-03-16  หญิง   NaN  NaN         NaN
# 406481  3276098    2022-03-17    2022-03-16   ชาย   NaN  NaN         NaN
#
#        province_of_isolation                                         risk  \
# ...

# %% [markdown]
# ## Data 5 Data COVID-19 ประจำวัน เริ่มตั้งแต่วันที่ 12 มกราคม 2563 ถึง 11 สิงหาคม 2564

# %%
data5 = pd.read_excel(os.path.join(path,'confirmed-cases.xlsx'))
data5
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 0            1    2020-01-12           NaT  หญิง  61.0   ปี       China
# 1            2    2020-01-17           NaT  หญิง  74.0   ปี       China
# 2            3    2020-01-22           NaT  หญิง  73.0   ปี    Thailand
# 3            4    2020-01-22           NaT   ชาย  68.0   ปี       China
# 4            5    2020-01-24           NaT  หญิง  66.0   ปี       China
# ...        ...           ...           ...   ...   ...  ...         ...
# 816984  816985    2021-08-11    2021-08-10  หญิง   8.0   ปี    Thailand
# 816985  816986    2021-08-11    2021-08-10   ชาย  14.0   ปี    Thailand
# 816986  816987    2021-08-11    2021-08-10   ชาย  59.0   ปี    Thailand
# 816987  816988    2021-08-11    2021-08-10  หญิง  34.0   ปี    Thailand
# 816988  816989    2021-08-11    2021-08-10  หญิง  19.0   ปี    Thailand
#
#        province_of_isolation  \
# 0              กรุงเทพมหานคร
# 1              กรุงเทพมหานคร
# ...

# %% [markdown]
# ## Data 6 Data ภูมิภาคในประเทศไทย

# %%
data6 = pd.read_csv(os.path.join(path,'data of region.csv'))
data6
# Out:
#     Unnamed: 0     จังหวัด 6 ภูมิภาค (ภูมิศาสตร์) 4 ภูมิภาค (การเมือง)  \
# 0            0  อำนาจเจริญ     ตะวันออกเฉียงเหนือ   ตะวันออกเฉียงเหนือ
# 1            1      บึงกาฬ     ตะวันออกเฉียงเหนือ   ตะวันออกเฉียงเหนือ
# 2            2   บุรีรัมย์     ตะวันออกเฉียงเหนือ   ตะวันออกเฉียงเหนือ
# 3            3     ชัยภูมิ     ตะวันออกเฉียงเหนือ   ตะวันออกเฉียงเหนือ
# 4            4   กาฬสินธุ์     ตะวันออกเฉียงเหนือ   ตะวันออกเฉียงเหนือ
# ..         ...         ...                    ...                  ...
# 72          72       พังงา                    ใต้                  ใต้
# 73          73      ภูเก็ต                    ใต้                  ใต้
# 74          74       ระนอง                    ใต้                  ใต้
# 75          75        สตูล                    ใต้                  ใต้
# 76          76        ตรัง                    ใต้                  ใต้
#
#          6 ภูมิภาค (อุตุนิยมวิทยา) 5 ภูมิภาค (การท่องเที่ยว)
# ...

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Data 1

# %% [markdown]
# ### ตรวจสอบค่า missing

# %%
data1.isnull().any()  # ตรวจสอบหาค่า missing
# Out:
# รหัสหน่วยงาน               False
# กระทรวง                    False
# กรม                        False
# หน่วยงาน                   False
# จังหวัด                    False
# หมุดที่ไม่พบความผิดปกติ    False
# ที่อยู่จุดบริการ            True
# ละติจูด                     True
# ลองติจูด                    True
# dtype: bool

# %% [markdown]
# จากการตรวจสอบพบว่าข้อมูลค่า missing เราจะทำการ dropna() เพื่อนำค่า missing นั้นออกไป

# %%
data1.dropna()   # dropna ลบค่า missing ออก
# Out:
#         รหัสหน่วยงาน        กระทรวง               กรม  \
# 0      8899021500001  กระทรวงกลาโหม    กรมแพทย์ทหารบก
# 2      8899021200001  กระทรวงกลาโหม  กรมแพทย์ทหารเรือ
# 3       111020400029  กระทรวงกลาโหม          กองทัพบก
# 4       113020400030  กระทรวงกลาโหม          กองทัพบก
# 5      8899020600012  กระทรวงกลาโหม       กองทัพอากาศ
# ...              ...            ...               ...
# 10709  8899417700034  กรุงเทพมหานคร       สำนักอนามัย
# 10710  8899417700072  กรุงเทพมหานคร       สำนักอนามัย
# 10711  8899417700052  กรุงเทพมหานคร       สำนักอนามัย
# 10712  8899417700073  กรุงเทพมหานคร       สำนักอนามัย
# 10713  8899417700032  กรุงเทพมหานคร       สำนักอนามัย
#
#                                           หน่วยงาน        จังหวัด  \
# 0                         โรงพยาบาลค่ายพิชัยดาบหัก      อุตรดิตถ์
# 2                         โรงพยาบาลทหารเรือกรุงเทพ  กรุงเทพมหานคร
# 3                  กองทัพบก โรงพยาบาลพระมงกุฎเกล้า  กรุงเทพมหานคร
# ...

# %%
# ตรวจสอบว่าข้อมูลหายไปเท่าไหร่
removes = data1.shape[0] - data1.dropna().shape[0]
print(f'size before drop = {data1.shape[0]}')
print(f'size after drop = {data1.dropna().shape[0]}')
print(f'we lost {100*(removes/data1.shape[0])}% of data')
# Out:
# size before drop = 10714
# size after drop = 10622
# we lost 0.8586895650550682% of data

# %% [markdown]
# จากการใช้ dropna() ในการลบค่า missing ออกไป เราได้ทำการตรวจเช็คว่าข้อมูลเราหายไปกี่เปอร์เซ็น จากการตรวจสอบพบว่าข้อมูลหายไปทั้งหมด 0.85% แสดงว่าเราใช้การ dropna() ในการลบค่า missing ได้

# %% [markdown]
# ## เชื่อมตารางข้อมูล

# %%
data_merged = pd.concat([data5,data2,data3,data4])   # เชื่อมข้อมูล COVID ทั้ง 4 ตารางเข้าด้วยกัน โดยใช้ pd.concat เป็นการต่อตารางในแนวนอน
data_merged
# Out:
#             No. announce_date Notified date   sex   age Unit nationality  \
# 0             1    2020-01-12           NaT  หญิง  61.0   ปี       China
# 1             2    2020-01-17           NaT  หญิง  74.0   ปี       China
# 2             3    2020-01-22           NaT  หญิง  73.0   ปี    Thailand
# 3             4    2020-01-22           NaT   ชาย  68.0   ปี       China
# 4             5    2020-01-24           NaT  หญิง  66.0   ปี       China
# ...         ...           ...           ...   ...   ...  ...         ...
# 406477  3276094    2022-03-17    2022-03-16   ชาย   NaN  NaN         NaN
# 406478  3276095    2022-03-17    2022-03-16   ชาย   NaN  NaN         NaN
# 406479  3276096    2022-03-17    2022-03-16   ชาย   NaN  NaN         NaN
# 406480  3276097    2022-03-17    2022-03-16  หญิง   NaN  NaN         NaN
# 406481  3276098    2022-03-17    2022-03-16   ชาย   NaN  NaN         NaN
#
#        province_of_isolation                              risk  \
# ...

# %% [markdown]
# จากการเชื่อตารางข้อมูล COVID ทั้งหมด เราจะทำการเลือกข้อมูลที่จะนำมาวิเคราะห์ ได้แก่ ลำดับ, วันที่, เพศ, อายุ, unit(หน่วยนับอายุ), province_of_isolationและ risk

# %%
data_merged1 = data_merged[['No.','announce_date','sex','age','Unit','province_of_isolation','risk']]   # ชี้ข้อมูลคอลัมน์ที่ต้องการ
data_merged1
# Out:
#             No. announce_date   sex   age Unit province_of_isolation  \
# 0             1    2020-01-12  หญิง  61.0   ปี         กรุงเทพมหานคร
# 1             2    2020-01-17  หญิง  74.0   ปี         กรุงเทพมหานคร
# 2             3    2020-01-22  หญิง  73.0   ปี                นครปฐม
# 3             4    2020-01-22   ชาย  68.0   ปี         กรุงเทพมหานคร
# 4             5    2020-01-24  หญิง  66.0   ปี               นนทบุรี
# ...         ...           ...   ...   ...  ...                   ...
# 406477  3276094    2022-03-17   ชาย   NaN  NaN         กรุงเทพมหานคร
# 406478  3276095    2022-03-17   ชาย   NaN  NaN         นครศรีธรรมราช
# 406479  3276096    2022-03-17   ชาย   NaN  NaN         นครศรีธรรมราช
# 406480  3276097    2022-03-17  หญิง   NaN  NaN             เชียงใหม่
# 406481  3276098    2022-03-17   ชาย   NaN  NaN              ปทุมธานี
#
#                                     risk
# 0       คนต่างชาติเดินทางมาจากต่างประเทศ
# 1       คนต่างชาติเดินทางมาจากต่างประเทศ
# ...

# %%
data_merged1.isnull().any()  # ตรวจสอบหาค่า missing
# Out:
# No.                      False
# announce_date            False
# sex                       True
# age                       True
# Unit                      True
# province_of_isolation     True
# risk                      True
# dtype: bool

# %% [markdown]
# จากการตรวจสอบพบว่าข้อมูลค่า missing เราจะทำการ dropna() เพื่อนำค่า missing นั้นออกไป

# %%
data_merged1.dropna()  # dropna ลบค่า missing ออก
# Out:
#             No. announce_date   sex   age Unit province_of_isolation  \
# 0             1    2020-01-12  หญิง  61.0   ปี         กรุงเทพมหานคร
# 1             2    2020-01-17  หญิง  74.0   ปี         กรุงเทพมหานคร
# 2             3    2020-01-22  หญิง  73.0   ปี                นครปฐม
# 3             4    2020-01-22   ชาย  68.0   ปี         กรุงเทพมหานคร
# 4             5    2020-01-24  หญิง  66.0   ปี               นนทบุรี
# ...         ...           ...   ...   ...  ...                   ...
# 406423  3276040    2022-03-17   ชาย  11.0   ปี         กรุงเทพมหานคร
# 406424  3276041    2022-03-17  หญิง  52.0   ปี         กรุงเทพมหานคร
# 406425  3276042    2022-03-17   ชาย  27.0   ปี         กรุงเทพมหานคร
# 406426  3276043    2022-03-17   ชาย  52.0   ปี         กรุงเทพมหานคร
# 406427  3276044    2022-03-17   ชาย  34.0   ปี         กรุงเทพมหานคร
#
#                                                  risk
# 0                    คนต่างชาติเดินทางมาจากต่างประเทศ
# ...

# %%
# ตรวจสอบว่าข้อมูลหายไปเท่าไหร่
removes = data_merged1.shape[0] - data_merged1.dropna().shape[0]
print(f'size before drop = {data_merged1.shape[0]}')
print(f'size after drop = {data_merged1.dropna().shape[0]}')
print(f'we lost {100*(removes/data_merged1.shape[0])}% of data')
# Out:
# size before drop = 3276098
# size after drop = 2891763
# we lost 11.731486664928827% of data

# %% [markdown]
# ### เชื่อมตารางข้อมูล COVID กับ ข้อมูลภูมิภาค

# %%
data6.isnull().any()   # ตรวจสอบหาค่า missing ของข้อมูลภูมิภาค
# Out:
# Unnamed: 0                   False
# จังหวัด                      False
# 6 ภูมิภาค (ภูมิศาสตร์)       False
# 4 ภูมิภาค (การเมือง)         False
# 6 ภูมิภาค (อุตุนิยมวิทยา)    False
# 5 ภูมิภาค (การท่องเที่ยว)    False
# dtype: bool

# %%
data_merged2 = data_merged1.merge(data6,how='left',left_on='province_of_isolation',right_on='จังหวัด')
data_merged2
#เชื่อมตาราง data_merged1 และ data6 โดยใช้ province_of_isolation และ จังหวัด เป็นตัวเชื่อมอ้างอิง เพราะเราจะพิจารณาข้อมูลที่มีค่าข้อมูลเหมือนกัน
# Out:
#              No. announce_date   sex   age Unit province_of_isolation  \
# 0              1    2020-01-12  หญิง  61.0   ปี         กรุงเทพมหานคร
# 1              2    2020-01-17  หญิง  74.0   ปี         กรุงเทพมหานคร
# 2              3    2020-01-22  หญิง  73.0   ปี                นครปฐม
# 3              4    2020-01-22   ชาย  68.0   ปี         กรุงเทพมหานคร
# 4              5    2020-01-24  หญิง  66.0   ปี               นนทบุรี
# ...          ...           ...   ...   ...  ...                   ...
# 3276093  3276094    2022-03-17   ชาย   NaN  NaN         กรุงเทพมหานคร
# 3276094  3276095    2022-03-17   ชาย   NaN  NaN         นครศรีธรรมราช
# 3276095  3276096    2022-03-17   ชาย   NaN  NaN         นครศรีธรรมราช
# 3276096  3276097    2022-03-17  หญิง   NaN  NaN             เชียงใหม่
# 3276097  3276098    2022-03-17   ชาย   NaN  NaN              ปทุมธานี
#
#                                      risk  Unnamed: 0        จังหวัด  \
# ...

# %% [markdown]
# จากการเชื่อตารางข้อมูล COVID ทั้งหมด เราจะทำการเลือกข้อมูลที่จะนำมาวิเคราะห์ ได้แก่ ลำดับ, วันที่, เพศ, อายุ, unit(หน่วยนับอายุ), province_of_isolation,  riskและ ข้อมูลภูมิคภาค โดยใช้ข้อมูลแบ่งภูมิภาค 6 ภูมิภาคโดยแบ่งแบบ ภูมิศาสตร์

# %%
data_merged3 = data_merged2[['No.','announce_date','sex','age','Unit','province_of_isolation','risk','จังหวัด','6 ภูมิภาค (ภูมิศาสตร์)']]
data_merged3
# Out:
#              No. announce_date   sex   age Unit province_of_isolation  \
# 0              1    2020-01-12  หญิง  61.0   ปี         กรุงเทพมหานคร
# 1              2    2020-01-17  หญิง  74.0   ปี         กรุงเทพมหานคร
# 2              3    2020-01-22  หญิง  73.0   ปี                นครปฐม
# 3              4    2020-01-22   ชาย  68.0   ปี         กรุงเทพมหานคร
# 4              5    2020-01-24  หญิง  66.0   ปี               นนทบุรี
# ...          ...           ...   ...   ...  ...                   ...
# 3276093  3276094    2022-03-17   ชาย   NaN  NaN         กรุงเทพมหานคร
# 3276094  3276095    2022-03-17   ชาย   NaN  NaN         นครศรีธรรมราช
# 3276095  3276096    2022-03-17   ชาย   NaN  NaN         นครศรีธรรมราช
# 3276096  3276097    2022-03-17  หญิง   NaN  NaN             เชียงใหม่
# 3276097  3276098    2022-03-17   ชาย   NaN  NaN              ปทุมธานี
#
#                                      risk        จังหวัด  \
# 0        คนต่างชาติเดินทางมาจากต่างประเทศ  กรุงเทพมหานคร
# ...

# %%
data_merged3.isnull().any()  # ตรวจสอบหาค่า missing
# Out:
# No.                       False
# announce_date             False
# sex                        True
# age                        True
# Unit                       True
# province_of_isolation      True
# risk                       True
# จังหวัด                    True
# 6 ภูมิภาค (ภูมิศาสตร์)     True
# dtype: bool

# %%
data_merged3.dropna()
# Out:
#              No. announce_date   sex   age Unit province_of_isolation  \
# 0              1    2020-01-12  หญิง  61.0   ปี         กรุงเทพมหานคร
# 1              2    2020-01-17  หญิง  74.0   ปี         กรุงเทพมหานคร
# 2              3    2020-01-22  หญิง  73.0   ปี                นครปฐม
# 3              4    2020-01-22   ชาย  68.0   ปี         กรุงเทพมหานคร
# 4              5    2020-01-24  หญิง  66.0   ปี               นนทบุรี
# ...          ...           ...   ...   ...  ...                   ...
# 3276039  3276040    2022-03-17   ชาย  11.0   ปี         กรุงเทพมหานคร
# 3276040  3276041    2022-03-17  หญิง  52.0   ปี         กรุงเทพมหานคร
# 3276041  3276042    2022-03-17   ชาย  27.0   ปี         กรุงเทพมหานคร
# 3276042  3276043    2022-03-17   ชาย  52.0   ปี         กรุงเทพมหานคร
# 3276043  3276044    2022-03-17   ชาย  34.0   ปี         กรุงเทพมหานคร
#
#                                                   risk        จังหวัด  \
# ...

# %%
# ตรวจสอบว่าข้อมูลหายไปเท่าไหร่
removes = data_merged3.shape[0] - data_merged3.dropna().shape[0]
print(f'size before drop = {data_merged3.shape[0]}')
print(f'size after drop = {data_merged3.dropna().shape[0]}')
print(f'we lost {100*(removes/data_merged3.shape[0])}% of data')
# Out:
# size before drop = 3276098
# size after drop = 2880777
# we lost 12.06682461879956% of data

# %% [markdown]
# จากการลบค่า missing ด้วยการ dropna() พบว่าข้อมูลหายไป 12.06 %

# %% [markdown]
# ### ลบค่า missing เฉพาะใน column ที่เราสนใจ

# %%
data_merged3_nomissingAge = data_merged3.dropna(subset=['age'])
data_merged3_nomissingAge
# Out:
#              No. announce_date   sex   age Unit province_of_isolation  \
# 0              1    2020-01-12  หญิง  61.0   ปี         กรุงเทพมหานคร
# 1              2    2020-01-17  หญิง  74.0   ปี         กรุงเทพมหานคร
# 2              3    2020-01-22  หญิง  73.0   ปี                นครปฐม
# 3              4    2020-01-22   ชาย  68.0   ปี         กรุงเทพมหานคร
# 4              5    2020-01-24  หญิง  66.0   ปี               นนทบุรี
# ...          ...           ...   ...   ...  ...                   ...
# 3276039  3276040    2022-03-17   ชาย  11.0   ปี         กรุงเทพมหานคร
# 3276040  3276041    2022-03-17  หญิง  52.0   ปี         กรุงเทพมหานคร
# 3276041  3276042    2022-03-17   ชาย  27.0   ปี         กรุงเทพมหานคร
# 3276042  3276043    2022-03-17   ชาย  52.0   ปี         กรุงเทพมหานคร
# 3276043  3276044    2022-03-17   ชาย  34.0   ปี         กรุงเทพมหานคร
#
#                                                   risk        จังหวัด  \
# ...

# %%
data_merged3_nomissingAge.isnull().any()  # ตรวจสอบหาค่า missing
# Out:
# No.                       False
# announce_date             False
# sex                        True
# age                       False
# Unit                       True
# province_of_isolation      True
# risk                       True
# จังหวัด                    True
# 6 ภูมิภาค (ภูมิศาสตร์)     True
# dtype: bool

# %%
# ตรวจสอบว่าข้อมูลหายไปเท่าไหร่
removes = data_merged3_nomissingAge.shape[0] - data_merged3_nomissingAge.dropna().shape[0]
print(f'size before drop = {data_merged3_nomissingAge.shape[0]}')
print(f'size after drop = {data_merged3_nomissingAge.dropna().shape[0]}')
print(f'we lost {100*(removes/data_merged3_nomissingAge.shape[0])}% of data')
# Out:
# size before drop = 3010468
# size after drop = 2880777
# we lost 4.308001280863972% of data

# %% [markdown]
# จากการลบค่า missing โดยลบเฉพาะคอลัมน์ที่เราสนใจพบว่าข้อมูลหาย 4.3 % แต่ยังมีข้อมูลที่มีค่า missing อยู่ จึงต้องใช้การแทนด้วย class ใหม่ (ค่าที่เหมาะสม)

# %% [markdown]
# ### แทนค่าในคอลัมน์ที่สนใจ class ใหม่ (ค่าที่เหมาะสม)

# %%
nomissingAge = data_merged3[['age']].mean() #หาค่าเฉลี่ยของอายุ
data_merged3[['age']] = data_merged3[['age']].fillna(nomissingAge) #แทนค่าเฉลี่ยของอายุลงในข้อมูลที่เป็นค่า missing
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
data_merged3[['sex']] = data_merged3[['sex']].fillna('ไม่ระบุ')   #แทนค่า Missing ในคอลัมน์ sex
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
data_merged3[['Unit']] = data_merged3[['Unit']].fillna('ปี')  #แทนค่า Missing ในคอลัมน์ unit
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
data_merged3[['province_of_isolation']] = data_merged3[['province_of_isolation']].fillna('ไม่ระบุ')  #แทนค่า Missing ในคอลัมน์ province_of_isolation
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
data_merged3[['risk']] = data_merged3[['risk']].fillna('ไม่ระบุ')  #แทนค่า Missing ในคอลัมน์ risk
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
data_merged3.isnull().any()  # ตรวจสอบหาค่า missing
# Out:
# No.                       False
# announce_date             False
# sex                       False
# age                        True
# Unit                      False
# province_of_isolation     False
# risk                      False
# จังหวัด                    True
# 6 ภูมิภาค (ภูมิศาสตร์)     True
# dtype: bool

# %%
data_merged3
# Out:
#              No. announce_date   sex   age Unit province_of_isolation  \
# 0              1    2020-01-12  หญิง  61.0   ปี         กรุงเทพมหานคร
# 1              2    2020-01-17  หญิง  74.0   ปี         กรุงเทพมหานคร
# 2              3    2020-01-22  หญิง  73.0   ปี                นครปฐม
# 3              4    2020-01-22   ชาย  68.0   ปี         กรุงเทพมหานคร
# 4              5    2020-01-24  หญิง  66.0   ปี               นนทบุรี
# ...          ...           ...   ...   ...  ...                   ...
# 3276093  3276094    2022-03-17   ชาย   NaN   ปี         กรุงเทพมหานคร
# 3276094  3276095    2022-03-17   ชาย   NaN   ปี         นครศรีธรรมราช
# 3276095  3276096    2022-03-17   ชาย   NaN   ปี         นครศรีธรรมราช
# 3276096  3276097    2022-03-17  หญิง   NaN   ปี             เชียงใหม่
# 3276097  3276098    2022-03-17   ชาย   NaN   ปี              ปทุมธานี
#
#                                      risk        จังหวัด  \
# 0        คนต่างชาติเดินทางมาจากต่างประเทศ  กรุงเทพมหานคร
# ...

# %%
data_merged3.dropna()  # ลบค่า missing
# Out:
#              No. announce_date   sex   age Unit province_of_isolation  \
# 0              1    2020-01-12  หญิง  61.0   ปี         กรุงเทพมหานคร
# 1              2    2020-01-17  หญิง  74.0   ปี         กรุงเทพมหานคร
# 2              3    2020-01-22  หญิง  73.0   ปี                นครปฐม
# 3              4    2020-01-22   ชาย  68.0   ปี         กรุงเทพมหานคร
# 4              5    2020-01-24  หญิง  66.0   ปี               นนทบุรี
# ...          ...           ...   ...   ...  ...                   ...
# 3276039  3276040    2022-03-17   ชาย  11.0   ปี         กรุงเทพมหานคร
# 3276040  3276041    2022-03-17  หญิง  52.0   ปี         กรุงเทพมหานคร
# 3276041  3276042    2022-03-17   ชาย  27.0   ปี         กรุงเทพมหานคร
# 3276042  3276043    2022-03-17   ชาย  52.0   ปี         กรุงเทพมหานคร
# 3276043  3276044    2022-03-17   ชาย  34.0   ปี         กรุงเทพมหานคร
#
#                                                   risk        จังหวัด  \
# ...

# %%
# ตรวจสอบว่าข้อมูลหายไปเท่าไหร่
removes = data_merged3.shape[0] - data_merged3.dropna().shape[0]
print(f'size before drop = {data_merged3.shape[0]}')
print(f'size after drop = {data_merged3.dropna().shape[0]}')
print(f'we lost {100*(removes/data_merged3.shape[0])}% of data')
# Out:
# size before drop = 3276098
# size after drop = 2995494
# we lost 8.565189441829885% of data

# %% [markdown]
# จากการแทนค่า missing ในคอลัมน์ที่สนใจ แล้วทำการ dropna() ข้อมูล พบว่าข้อมูลหายไป 8.5 %

# %%
data_df = data_merged3.dropna()
data_df
# Out:
#              No. announce_date   sex   age Unit province_of_isolation  \
# 0              1    2020-01-12  หญิง  61.0   ปี         กรุงเทพมหานคร
# 1              2    2020-01-17  หญิง  74.0   ปี         กรุงเทพมหานคร
# 2              3    2020-01-22  หญิง  73.0   ปี                นครปฐม
# 3              4    2020-01-22   ชาย  68.0   ปี         กรุงเทพมหานคร
# 4              5    2020-01-24  หญิง  66.0   ปี               นนทบุรี
# ...          ...           ...   ...   ...  ...                   ...
# 3276039  3276040    2022-03-17   ชาย  11.0   ปี         กรุงเทพมหานคร
# 3276040  3276041    2022-03-17  หญิง  52.0   ปี         กรุงเทพมหานคร
# 3276041  3276042    2022-03-17   ชาย  27.0   ปี         กรุงเทพมหานคร
# 3276042  3276043    2022-03-17   ชาย  52.0   ปี         กรุงเทพมหานคร
# 3276043  3276044    2022-03-17   ชาย  34.0   ปี         กรุงเทพมหานคร
#
#                                                   risk        จังหวัด  \
# ...

# %% [markdown]
# ### เชื่อมตารางภูมิภาค กับ ตารางพิกัดโรงพยาบาล

# %%
data1_cut = data1[['หน่วยงาน','จังหวัด','ที่อยู่จุดบริการ','ละติจูด','ลองติจูด']]  # เลือกมาแค่ข้อมูลที่ต้องการ
data1_cut
# Out:
#                                           หน่วยงาน        จังหวัด  \
# 0                         โรงพยาบาลค่ายพิชัยดาบหัก      อุตรดิตถ์
# 1               โรงพยาบาลสมเด็จพระนางเจ้าสิริกิติ์         ชลบุรี
# 2                         โรงพยาบาลทหารเรือกรุงเทพ  กรุงเทพมหานคร
# 3                  กองทัพบก โรงพยาบาลพระมงกุฎเกล้า  กรุงเทพมหานคร
# 4                    กองทัพบก โรงพยาบาลอานันทมหิดล         ลพบุรี
# ...                                            ...            ...
# 10709           ศูนย์บริการสาธารณสุข 21 วัดธาตุทอง  กรุงเทพมหานคร
# 10710              ศูนย์บริการสาธารณสุข 59 ทุ่งครุ  กรุงเทพมหานคร
# 10711          ศูนย์บริการสาธารณสุข 39 ราษฎร์บูรณะ  กรุงเทพมหานคร
# 10712  ศูนย์บริการสาธารณสุข 60 รสสุคนธ์ มโนชญากรณ์  กรุงเทพมหานคร
# 10713            ศูนย์บริการสาธารณสุข 19 วงศ์สว่าง  กรุงเทพมหานคร
#
#                                         ที่อยู่จุดบริการ    ละติจูด  \
# 0      102 หมู่ 8 ต.ท่าเสา อ.เมืองอุตรดิตถ์ จ.อุตรดิต...  17.662624
# ...

# %%
data1_merged = data1_cut.merge(data6,how='left',left_on='จังหวัด',right_on='จังหวัด')
data1_merged 
#เชื่อมตาราง data1_cut และ data6 โดยใช้ จังหวัด เป็นตัวเชื่อมอ้างอิง เพราะเราจะพิจารณาข้อมูลที่มีค่าข้อมูลเหมือนกัน
# Out:
#                                           หน่วยงาน        จังหวัด  \
# 0                         โรงพยาบาลค่ายพิชัยดาบหัก      อุตรดิตถ์
# 1               โรงพยาบาลสมเด็จพระนางเจ้าสิริกิติ์         ชลบุรี
# 2                         โรงพยาบาลทหารเรือกรุงเทพ  กรุงเทพมหานคร
# 3                  กองทัพบก โรงพยาบาลพระมงกุฎเกล้า  กรุงเทพมหานคร
# 4                    กองทัพบก โรงพยาบาลอานันทมหิดล         ลพบุรี
# ...                                            ...            ...
# 10709           ศูนย์บริการสาธารณสุข 21 วัดธาตุทอง  กรุงเทพมหานคร
# 10710              ศูนย์บริการสาธารณสุข 59 ทุ่งครุ  กรุงเทพมหานคร
# 10711          ศูนย์บริการสาธารณสุข 39 ราษฎร์บูรณะ  กรุงเทพมหานคร
# 10712  ศูนย์บริการสาธารณสุข 60 รสสุคนธ์ มโนชญากรณ์  กรุงเทพมหานคร
# 10713            ศูนย์บริการสาธารณสุข 19 วงศ์สว่าง  กรุงเทพมหานคร
#
#                                         ที่อยู่จุดบริการ    ละติจูด  \
# 0      102 หมู่ 8 ต.ท่าเสา อ.เมืองอุตรดิตถ์ จ.อุตรดิต...  17.662624
# ...

# %%
data1_cut2 = data1_merged[['หน่วยงาน','จังหวัด','ที่อยู่จุดบริการ','ละติจูด','ลองติจูด','6 ภูมิภาค (ภูมิศาสตร์)']]  # เลือกข้อมูลที่ต้องการ
data1_cut2
# Out:
#                                           หน่วยงาน        จังหวัด  \
# 0                         โรงพยาบาลค่ายพิชัยดาบหัก      อุตรดิตถ์
# 1               โรงพยาบาลสมเด็จพระนางเจ้าสิริกิติ์         ชลบุรี
# 2                         โรงพยาบาลทหารเรือกรุงเทพ  กรุงเทพมหานคร
# 3                  กองทัพบก โรงพยาบาลพระมงกุฎเกล้า  กรุงเทพมหานคร
# 4                    กองทัพบก โรงพยาบาลอานันทมหิดล         ลพบุรี
# ...                                            ...            ...
# 10709           ศูนย์บริการสาธารณสุข 21 วัดธาตุทอง  กรุงเทพมหานคร
# 10710              ศูนย์บริการสาธารณสุข 59 ทุ่งครุ  กรุงเทพมหานคร
# 10711          ศูนย์บริการสาธารณสุข 39 ราษฎร์บูรณะ  กรุงเทพมหานคร
# 10712  ศูนย์บริการสาธารณสุข 60 รสสุคนธ์ มโนชญากรณ์  กรุงเทพมหานคร
# 10713            ศูนย์บริการสาธารณสุข 19 วงศ์สว่าง  กรุงเทพมหานคร
#
#                                         ที่อยู่จุดบริการ    ละติจูด  \
# 0      102 หมู่ 8 ต.ท่าเสา อ.เมืองอุตรดิตถ์ จ.อุตรดิต...  17.662624
# ...

# %%
data1_cut2.isnull().any()
# Out:
# หน่วยงาน                  False
# จังหวัด                   False
# ที่อยู่จุดบริการ           True
# ละติจูด                    True
# ลองติจูด                   True
# 6 ภูมิภาค (ภูมิศาสตร์)     True
# dtype: bool

# %%
data1_cut2.dropna()  # ลบค่า missing
# Out:
#                                           หน่วยงาน        จังหวัด  \
# 0                         โรงพยาบาลค่ายพิชัยดาบหัก      อุตรดิตถ์
# 2                         โรงพยาบาลทหารเรือกรุงเทพ  กรุงเทพมหานคร
# 3                  กองทัพบก โรงพยาบาลพระมงกุฎเกล้า  กรุงเทพมหานคร
# 4                    กองทัพบก โรงพยาบาลอานันทมหิดล         ลพบุรี
# 5        โรงพยาบาลภูมิพลอดุลยเดช กรมแพทย์ทหารอากาศ  กรุงเทพมหานคร
# ...                                            ...            ...
# 10709           ศูนย์บริการสาธารณสุข 21 วัดธาตุทอง  กรุงเทพมหานคร
# 10710              ศูนย์บริการสาธารณสุข 59 ทุ่งครุ  กรุงเทพมหานคร
# 10711          ศูนย์บริการสาธารณสุข 39 ราษฎร์บูรณะ  กรุงเทพมหานคร
# 10712  ศูนย์บริการสาธารณสุข 60 รสสุคนธ์ มโนชญากรณ์  กรุงเทพมหานคร
# 10713            ศูนย์บริการสาธารณสุข 19 วงศ์สว่าง  กรุงเทพมหานคร
#
#                                         ที่อยู่จุดบริการ    ละติจูด  \
# 0      102 หมู่ 8 ต.ท่าเสา อ.เมืองอุตรดิตถ์ จ.อุตรดิต...  17.662624
# ...

# %%
removes = data1_cut2.shape[0] - data1_cut2.dropna().shape[0]
print(f'size before drop = {data1_cut2.shape[0]}')
print(f'size after drop = {data1_cut2.dropna().shape[0]}')
print(f'we lost {100*(removes/data1_cut2.shape[0])}% of data')
# Out:
# size before drop = 10714
# size after drop = 10393
# we lost 2.996079895463879% of data

# %% [markdown]
# จากการใช้ dropna() ในการลบค่า missing พบว่าข้อมูลหายไป 2.99%

# %%
data_gps = data1_cut2.dropna()
data_gps
# Out:
#                                           หน่วยงาน        จังหวัด  \
# 0                         โรงพยาบาลค่ายพิชัยดาบหัก      อุตรดิตถ์
# 2                         โรงพยาบาลทหารเรือกรุงเทพ  กรุงเทพมหานคร
# 3                  กองทัพบก โรงพยาบาลพระมงกุฎเกล้า  กรุงเทพมหานคร
# 4                    กองทัพบก โรงพยาบาลอานันทมหิดล         ลพบุรี
# 5        โรงพยาบาลภูมิพลอดุลยเดช กรมแพทย์ทหารอากาศ  กรุงเทพมหานคร
# ...                                            ...            ...
# 10709           ศูนย์บริการสาธารณสุข 21 วัดธาตุทอง  กรุงเทพมหานคร
# 10710              ศูนย์บริการสาธารณสุข 59 ทุ่งครุ  กรุงเทพมหานคร
# 10711          ศูนย์บริการสาธารณสุข 39 ราษฎร์บูรณะ  กรุงเทพมหานคร
# 10712  ศูนย์บริการสาธารณสุข 60 รสสุคนธ์ มโนชญากรณ์  กรุงเทพมหานคร
# 10713            ศูนย์บริการสาธารณสุข 19 วงศ์สว่าง  กรุงเทพมหานคร
#
#                                         ที่อยู่จุดบริการ    ละติจูด  \
# 0      102 หมู่ 8 ต.ท่าเสา อ.เมืองอุตรดิตถ์ จ.อุตรดิต...  17.662624
# ...

# %%
data_gps1 = data_gps.reset_index(drop=True)
data_gps1
# Out:
#                                           หน่วยงาน        จังหวัด  \
# 0                         โรงพยาบาลค่ายพิชัยดาบหัก      อุตรดิตถ์
# 1                         โรงพยาบาลทหารเรือกรุงเทพ  กรุงเทพมหานคร
# 2                  กองทัพบก โรงพยาบาลพระมงกุฎเกล้า  กรุงเทพมหานคร
# 3                    กองทัพบก โรงพยาบาลอานันทมหิดล         ลพบุรี
# 4        โรงพยาบาลภูมิพลอดุลยเดช กรมแพทย์ทหารอากาศ  กรุงเทพมหานคร
# ...                                            ...            ...
# 10388           ศูนย์บริการสาธารณสุข 21 วัดธาตุทอง  กรุงเทพมหานคร
# 10389              ศูนย์บริการสาธารณสุข 59 ทุ่งครุ  กรุงเทพมหานคร
# 10390          ศูนย์บริการสาธารณสุข 39 ราษฎร์บูรณะ  กรุงเทพมหานคร
# 10391  ศูนย์บริการสาธารณสุข 60 รสสุคนธ์ มโนชญากรณ์  กรุงเทพมหานคร
# 10392            ศูนย์บริการสาธารณสุข 19 วงศ์สว่าง  กรุงเทพมหานคร
#
#                                         ที่อยู่จุดบริการ    ละติจูด  \
# 0      102 หมู่ 8 ต.ท่าเสา อ.เมืองอุตรดิตถ์ จ.อุตรดิต...  17.662624
# ...

# %% [markdown]
# # Export Data

# %%
data_df
# Out:
#              No. announce_date   sex   age Unit province_of_isolation  \
# 0              1    2020-01-12  หญิง  61.0   ปี         กรุงเทพมหานคร
# 1              2    2020-01-17  หญิง  74.0   ปี         กรุงเทพมหานคร
# 2              3    2020-01-22  หญิง  73.0   ปี                นครปฐม
# 3              4    2020-01-22   ชาย  68.0   ปี         กรุงเทพมหานคร
# 4              5    2020-01-24  หญิง  66.0   ปี               นนทบุรี
# ...          ...           ...   ...   ...  ...                   ...
# 3276039  3276040    2022-03-17   ชาย  11.0   ปี         กรุงเทพมหานคร
# 3276040  3276041    2022-03-17  หญิง  52.0   ปี         กรุงเทพมหานคร
# 3276041  3276042    2022-03-17   ชาย  27.0   ปี         กรุงเทพมหานคร
# 3276042  3276043    2022-03-17   ชาย  52.0   ปี         กรุงเทพมหานคร
# 3276043  3276044    2022-03-17   ชาย  34.0   ปี         กรุงเทพมหานคร
#
#                                                   risk        จังหวัด  \
# ...

# %%
set(data_df['6 ภูมิภาค (ภูมิศาสตร์)'])
# Out:
# {'กลาง', 'ตะวันตก', 'ตะวันออก', 'ตะวันออกเฉียงเหนือ', 'เหนือ', 'ใต้'}

# %%
data_df1 = data_df[(data_df['6 ภูมิภาค (ภูมิศาสตร์)']=='กลาง') |
                   (data_df['6 ภูมิภาค (ภูมิศาสตร์)']=='ตะวันตก') |
                   (data_df['6 ภูมิภาค (ภูมิศาสตร์)']=='ตะวันออก')]
data_df1
# Out:
#              No. announce_date   sex   age Unit province_of_isolation  \
# 0              1    2020-01-12  หญิง  61.0   ปี         กรุงเทพมหานคร
# 1              2    2020-01-17  หญิง  74.0   ปี         กรุงเทพมหานคร
# 2              3    2020-01-22  หญิง  73.0   ปี                นครปฐม
# 3              4    2020-01-22   ชาย  68.0   ปี         กรุงเทพมหานคร
# 4              5    2020-01-24  หญิง  66.0   ปี               นนทบุรี
# ...          ...           ...   ...   ...  ...                   ...
# 3276039  3276040    2022-03-17   ชาย  11.0   ปี         กรุงเทพมหานคร
# 3276040  3276041    2022-03-17  หญิง  52.0   ปี         กรุงเทพมหานคร
# 3276041  3276042    2022-03-17   ชาย  27.0   ปี         กรุงเทพมหานคร
# 3276042  3276043    2022-03-17   ชาย  52.0   ปี         กรุงเทพมหานคร
# 3276043  3276044    2022-03-17   ชาย  34.0   ปี         กรุงเทพมหานคร
#
#                                                   risk        จังหวัด  \
# ...

# %%
data_df2 = data_df[(data_df['6 ภูมิภาค (ภูมิศาสตร์)']=='ตะวันออกเฉียงเหนือ') |
                   (data_df['6 ภูมิภาค (ภูมิศาสตร์)']=='เหนือ') |
                   (data_df['6 ภูมิภาค (ภูมิศาสตร์)']=='ใต้')]
data_df2
# Out:
#              No. announce_date   sex   age   Unit province_of_isolation  \
# 13            14    2020-01-28  หญิง  32.0     ปี                ภูเก็ต
# 16            17    2020-01-31   ชาย  28.0     ปี             เชียงใหม่
# 23            24    2020-02-04  หญิง  31.0     ปี                กระบี่
# 25            26    2020-02-08   ชาย  36.0     ปี                ภูเก็ต
# 46            47    2020-03-05   ชาย  22.0     ปี         นครศรีธรรมราช
# ...          ...           ...   ...   ...    ...                   ...
# 3272336  3272337    2022-03-17  หญิง  37.0     ปี                  ยะลา
# 3272337  3272338    2022-03-17  หญิง   3.0  เดือน                  ยะลา
# 3272338  3272339    2022-03-17   ชาย   4.0     ปี                  ยะลา
# 3272339  3272340    2022-03-17   ชาย   4.0  เดือน                  ยะลา
# 3272340  3272341    2022-03-17   ชาย   9.0     ปี                  ยะลา
#
#                                                 risk        จังหวัด  \
# ...

# %%
data_df3 = data_df1.reset_index(drop=True)
data_df3
# Out:
#              No. announce_date   sex   age Unit province_of_isolation  \
# 0              1    2020-01-12  หญิง  61.0   ปี         กรุงเทพมหานคร
# 1              2    2020-01-17  หญิง  74.0   ปี         กรุงเทพมหานคร
# 2              3    2020-01-22  หญิง  73.0   ปี                นครปฐม
# 3              4    2020-01-22   ชาย  68.0   ปี         กรุงเทพมหานคร
# 4              5    2020-01-24  หญิง  66.0   ปี               นนทบุรี
# ...          ...           ...   ...   ...  ...                   ...
# 2043500  3276040    2022-03-17   ชาย  11.0   ปี         กรุงเทพมหานคร
# 2043501  3276041    2022-03-17  หญิง  52.0   ปี         กรุงเทพมหานคร
# 2043502  3276042    2022-03-17   ชาย  27.0   ปี         กรุงเทพมหานคร
# 2043503  3276043    2022-03-17   ชาย  52.0   ปี         กรุงเทพมหานคร
# 2043504  3276044    2022-03-17   ชาย  34.0   ปี         กรุงเทพมหานคร
#
#                                                   risk        จังหวัด  \
# ...

# %%
data_df4 = data_df2.reset_index(drop=True)
data_df4
# Out:
#             No. announce_date   sex   age   Unit province_of_isolation  \
# 0            14    2020-01-28  หญิง  32.0     ปี                ภูเก็ต
# 1            17    2020-01-31   ชาย  28.0     ปี             เชียงใหม่
# 2            24    2020-02-04  หญิง  31.0     ปี                กระบี่
# 3            26    2020-02-08   ชาย  36.0     ปี                ภูเก็ต
# 4            47    2020-03-05   ชาย  22.0     ปี         นครศรีธรรมราช
# ...         ...           ...   ...   ...    ...                   ...
# 951984  3272337    2022-03-17  หญิง  37.0     ปี                  ยะลา
# 951985  3272338    2022-03-17  หญิง   3.0  เดือน                  ยะลา
# 951986  3272339    2022-03-17   ชาย   4.0     ปี                  ยะลา
# 951987  3272340    2022-03-17   ชาย   4.0  เดือน                  ยะลา
# 951988  3272341    2022-03-17   ชาย   9.0     ปี                  ยะลา
#
#                                                risk        จังหวัด  \
# ...

# %% [markdown]
# ## ข้อมูลที่จะใช้ ได้แก่
# 1. data_gps1 เป็นข้อมูล พิกัดสถานพยาบาล
# 2. data_df3   เป็นข้อมูล โควิดของภาคกลาง ตะวันตกและตะวันออก
# 3. data_df4   เป็นข้อมูล โควิดของภาคตะวันออกเฉียงเหนือ ภาคเหนือและภาคใต้

# %% [markdown]
# ## Save table

# %%
data_gps1.to_csv(os.path.join(path,'data_gps.csv'))  # save ไปเก็บในไดร์ฟ

# %%
data_df3.to_csv(os.path.join(path,'data_df1.csv'))  # save ไปเก็บในไดร์ฟ

# %%
data_df4.to_csv(os.path.join(path,'data_df2.csv'))  # save ไปเก็บในไดร์ฟ
