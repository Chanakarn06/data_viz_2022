# %% [markdown]
# <a href="https://colab.research.google.com/github/Chanakarn06/data_viz_2022/blob/main/Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#โหลด data
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # ตารางที่1 ข้อมูลผู้ป่วยปี2020

# %%
data1= pd.read_excel('/content/drive/MyDrive/Project_Dashboard2022/confirmed-cases.xlsx')  ## สร้างตัวแปร รับค่าข้อมูลที่อยู่ใน Google drive
data1 ## แสดงข้อมูล
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 0            1    2020-01-12           NaT  หญิง  61.0   ปี       China
# 1            2    2020-01-17           NaT  หญิง  74.0   ปี       China
# 2            3    2020-01-22           NaT  หญิง  73.0   ปี    Thailand
# 3            4    2020-01-22           NaT   ชาย  68.0   ปี       China
# 4            5    2020-01-24           NaT  หญิง  66.0   ปี       China
# ...        ...           ...           ...   ...   ...  ...         ...
# 816984  816985    2021-08-11    2021-08-10  หญิง   8.0   ปี    Thailand
# 816985  816986    2021-08-11    2021-08-10   ชาย  14.0   ปี    Thailand
# 816986  816987    2021-08-11    2021-08-10   ชาย  59.0   ปี    Thailand
# 816987  816988    2021-08-11    2021-08-10  หญิง  34.0   ปี    Thailand
# 816988  816989    2021-08-11    2021-08-10  หญิง  19.0   ปี    Thailand
#
#        province_of_isolation  \
# 0              กรุงเทพมหานคร
# 1              กรุงเทพมหานคร
# ...

# %% [markdown]
# # ตารางที่2 ข้อมูลผู้ป่วยปี2021- 2021เดือน10 วันที่25

# %%
data2= pd.read_excel('/content/drive/MyDrive/Project_Dashboard2022/confirmed-cases-since-120864.xlsx')  ## สร้างตัวแปร รับค่าข้อมูลที่อยู่ใน Google drive
data2 ## แสดงข้อมูล
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-d9088d5ec758> in <module>()
# ----> 1 data2= pd.read_excel('/content/drive/MyDrive/Project_Dashboard2022/confirmed-cases-since-120864.xlsx')  ## สร้างตัวแปร รับค่าข้อมูลที่อยู่ใน Google drive
#       2 data2 ## แสดงข้อมูล
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %% [markdown]
# # ตารางที่3 ข้อมูลผู้ป่วยปี2021เดือน10 วันที่26เป็นต้นไป

# %%
data3= pd.read_excel('/content/drive/MyDrive/Project_Dashboard2022/confirmed-cases-since-271064.xlsx')  ## สร้างตัวแปร รับค่าข้อมูลที่อยู่ใน Google drive
data3 ## แสดงข้อมูล

# %% [markdown]
# # ตารางที่4 ข้อมูลผู้ป่วยปี2022

# %%
data4= pd.read_excel('/content/drive/MyDrive/Project_Dashboard2022/confirmed-cases-since-280265 (1).xlsx')  ## สร้างตัวแปร รับค่าข้อมูลที่อยู่ใน Google drive
data4 ## แสดงข้อมูล

# %%
#โหลด data
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data_co= pd.read_excel('/content/drive/MyDrive/Project_Dashboard2022/citizeninfo_health_20200314 (3).xlsx')  ## สร้างตัวแปร รับค่าข้อมูลที่อยู่ใน Google drive
data_co## แสดงข้อมูล
# Out:
#         รหัสหน่วยงาน        กระทรวง               กรม  \
# 0      8899021500001  กระทรวงกลาโหม    กรมแพทย์ทหารบก
# 1      8899021200003  กระทรวงกลาโหม  กรมแพทย์ทหารเรือ
# 2      8899021200001  กระทรวงกลาโหม  กรมแพทย์ทหารเรือ
# 3       111020400029  กระทรวงกลาโหม          กองทัพบก
# 4       113020400030  กระทรวงกลาโหม          กองทัพบก
# ...              ...            ...               ...
# 10709  8899417700034  กรุงเทพมหานคร       สำนักอนามัย
# 10710  8899417700072  กรุงเทพมหานคร       สำนักอนามัย
# 10711  8899417700052  กรุงเทพมหานคร       สำนักอนามัย
# 10712  8899417700073  กรุงเทพมหานคร       สำนักอนามัย
# 10713  8899417700032  กรุงเทพมหานคร       สำนักอนามัย
#
#                                           หน่วยงาน หมุดที่ไม่พบความผิดปกติ  \
# 0                         โรงพยาบาลค่ายพิชัยดาบหัก                       Y
# 1               โรงพยาบาลสมเด็จพระนางเจ้าสิริกิติ์                       N
# 2                         โรงพยาบาลทหารเรือกรุงเทพ                       Y
# ...

# %%
data_co.dropna()
# Out:
#         รหัสหน่วยงาน        กระทรวง               กรม  \
# 0      8899021500001  กระทรวงกลาโหม    กรมแพทย์ทหารบก
# 2      8899021200001  กระทรวงกลาโหม  กรมแพทย์ทหารเรือ
# 3       111020400029  กระทรวงกลาโหม          กองทัพบก
# 4       113020400030  กระทรวงกลาโหม          กองทัพบก
# 5      8899020600012  กระทรวงกลาโหม       กองทัพอากาศ
# ...              ...            ...               ...
# 10709  8899417700034  กรุงเทพมหานคร       สำนักอนามัย
# 10710  8899417700072  กรุงเทพมหานคร       สำนักอนามัย
# 10711  8899417700052  กรุงเทพมหานคร       สำนักอนามัย
# 10712  8899417700073  กรุงเทพมหานคร       สำนักอนามัย
# 10713  8899417700032  กรุงเทพมหานคร       สำนักอนามัย
#
#                                           หน่วยงาน หมุดที่ไม่พบความผิดปกติ  \
# 0                         โรงพยาบาลค่ายพิชัยดาบหัก                       Y
# 2                         โรงพยาบาลทหารเรือกรุงเทพ                       Y
# 3                  กองทัพบก โรงพยาบาลพระมงกุฎเกล้า                       Y
# ...

# %%
# !pip install folium

# %%
import folium # package สำหรับ visualize interactive map

# %%
from branca.element import Figure  # จัดการขนาดของ map

# %%
fig=Figure(width=550,height=350)

# %%
fig2=Figure(width=550,height=350)

mt=folium.Map(location=[16.4743, 102.8222],zoom_start=14)
folium.Marker(location=[16.47447720294497, 102.8230673655105],popup='SC06',tooltip='Science').add_to(mt) # mouse over = tooltip, click = popup

fig2.add_child(mt)
# Out:
# <iframe src="about:blank" width="550" height="350"style="border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20
# ...
